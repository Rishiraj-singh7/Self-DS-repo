# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Rishi\Downloads\peoplee.csv")

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isna()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
df.isna().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['dept'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'IT',
#        'product_mng', 'marketing', 'management', 'RandD'], dtype=object)

# %%
df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
df['numberOfProjects'].unique()
# Out:
# array([2, 5, 7, 6, 4, 3], dtype=int64)

# %%
df.head(4)
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low

# %%
df['left'].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['satisfactoryLevel'])
plt.show()

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
for i in df.columns:
    if df[i].dtype != 'object':
        plt.boxplot(df[i])
        plt.title(i)
        plt.show()

# %%
sns.countplot(x = 'numberOfProjects', data = df, hue = 'left')
plt.show()

# %%
sns.countplot(x = 'timeSpent.company', data = df, hue = 'left')
plt.show()

# %%
sns.countplot(x = 'salary', data = df, hue = 'left')
plt.show()

# %%
df['avgMonthlyHours'].unique()
# Out:
# array([157, 262, 272, 159, 153, 247, 259, 142, 135, 305, 137, 143, 160,
#        255, 282, 304, 139, 158, 242, 239, 132, 294, 134, 145, 246, 126,
#        306, 269, 281, 276, 273, 147, 152, 307, 140, 128, 244, 223, 277,
#        275, 149, 295, 130, 291, 155, 265, 279, 284, 221, 154, 150, 267,
#        177, 144, 289, 258, 251, 133, 138, 183, 250, 151, 283, 249, 257,
#        245, 256, 278, 240, 136, 301, 243, 260, 296, 129, 274, 164, 148,
#        127, 146, 261, 285, 141, 297, 226, 219, 254, 228, 225, 252, 236,
#        270, 156, 298, 248, 287, 131, 229, 233, 268, 292, 232, 300, 253,
#        266, 271, 290, 308, 263, 235, 238, 218, 264, 199, 180, 195, 309,
#        234, 227, 181, 293, 237, 310, 198, 222, 286, 213, 202, 216, 214,
#        204, 161, 288, 224, 299, 303, 220, 212, 196, 241, 205, 217, 302,
#        169, 280, 188, 179, 231, 230, 175, 166, 206, 168, 165, 189, 162,
#        193, 176, 191, 174, 201, 208, 171, 178, 111, 104, 106, 100, 194,
# ...

# %%
sns.countplot(x = 'avgMonthlyHours', data = df, hue = 'left')
plt.show()

# %%
for i in df.columns:
        sns.countplot(x = i, data = df, hue ='left')
        plt.title(i)
        plt.show()

# %%
dff =df.sample(n =50)

# %%
dff
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 6523                0.72            0.78                 3              229
# 10640               0.75            0.99                 5              189
# 6328                0.25            0.87                 3              265
# 14253               0.37            0.52                 2              144
# 800                 0.38            0.55                 2              134
# 8556                0.52            0.37                 2              118
# 4350                0.68            0.71                 3              237
# 2170                0.90            0.76                 2              211
# 647                 0.45            0.45                 2              140
# 11531               0.61            0.73                 3              165
# 8391                0.51            0.83                 5              249
# ...

# %%
sns.countplot(x = 'avgMonthlyHours', data = dff, hue = 'left')
plt.show()
