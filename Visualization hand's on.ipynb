# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Q1 Create scatter plots for the following data, make sure all the plots appear
# in the same plane with x-labels and y-labels evenly spaced.
#
# a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg,hp-time-to-60) with respect to each brand.

# %%
df = pd.read_csv(r'C:\Users\Rishi\Downloads\cars.csv')
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
#mpg-hp
sns.scatterplot(x = 'mpg',y = 'hp', data = df)
plt.show()

# %%
# mpg-weight
sns.scatterplot(x = 'mpg', y = 'weightlbs', data = df)
plt.show()

# %%
# hp-mpg
sns.scatterplot(x = 'hp', y = 'mpg', data = df)
plt.show()

# %%
# hp-time-to-60
sns.scatterplot(x = 'hp', y = 'time-to-60', data = df)
plt.show()

# %%
fig = plt.subplots(2,2, figsize =(20,10))

plt.subplot(2,2,1)
sns.scatterplot(x = 'mpg',y = 'hp', data = df,hue = 'brand', palette='Set1')

plt.subplot(2,2,2)
sns.scatterplot(x = 'mpg', y = 'weightlbs', data = df,hue = 'brand', palette='Set2')

plt.subplot(2,2,3)
sns.scatterplot(x = 'hp', y = 'mpg', data = df,hue = 'brand', palette='Set2')

plt.subplot(2,2,4)
sns.scatterplot(x = 'hp', y = 'time-to-60', data = df,hue = 'brand', palette='Set2')
plt.show()

# %%
df['brand'].unique()
# Out:
# array([' US.', ' Europe.', ' Japan.'], dtype=object)

# %% [markdown]
# Q2
# Create bar plots for the following, make sure all the plots appear in the same plane with
# x-labels and y-labels evenly spaced.
#
#
# a. Create a bar plot that shows the visual representation of hp, mpg, weight,
# time-to-60 with respect to the number of cylinders for each of the brands.
#
# b. Create a bar plot that shows the visual representation of hp, mpg, weight and
# time-to-60 with respect to the years, for each brand.

# %%
fig = plt.subplots(2,2, figsize = (30,20))

x1 = df['hp']
x2 = df['mpg']
x3 = df['weightlbs']
x4 = df['time-to-60']

plt.subplot(2,2,1)
sns.barplot(x = x1, y = 'cylinders', data = df)

plt.subplot(2,2,2)
sns.barplot(x = x2, y = 'cylinders', data = df)

plt.subplot(2,2,3)
sns.barplot(x = x3, y = 'cylinders', data = df)

plt.subplot(2,2,4)
sns.barplot(x = x4, y = 'cylinders', data = df)

plt.show()

# %%
short_df = df.head(30)
short_df
# Out:
#      mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0   14.0          8         350  165      4209          12  1972       US.
# 1   31.9          4          89   71      1925          14  1980   Europe.
# 2   17.0          8         302  140      3449          11  1971       US.
# 3   15.0          8         400  150      3761          10  1971       US.
# 4   30.5          4          98   63      2051          17  1978       US.
# 5   23.0          8         350  125      3900          17  1980       US.
# 6   13.0          8         351  158      4363          13  1974       US.
# 7   14.0          8         440  215      4312           9  1971       US.
# 8   25.4          5         183   77      3530          20  1980   Europe.
# 9   37.7          4          89   62      2050          17  1982    Japan.
# 10  34.0          4         108   70      2245          17  1983    Japan.
# ...

# %%
fig = plt.subplots(2,2, figsize = (20,10))

x1 = short_df['hp']
x2 = short_df['mpg']
x3 = short_df['weightlbs']
x4 = short_df['time-to-60']

plt.subplot(2,2,1)
sns.barplot(x = x1, y = 'cylinders', data = short_df)

plt.subplot(2,2,2)
sns.barplot(x = x2, y = 'cylinders', data = short_df)

plt.subplot(2,2,3)
sns.barplot(x = x3, y = 'cylinders', data = short_df)

plt.subplot(2,2,4)
sns.barplot(x = x4, y = 'cylinders', data = short_df)

plt.show()

# %%
#section B

fig = plt.subplots(2,2, figsize = (20,10))
x1 = short_df['hp']
x2 = short_df['mpg']
x3= short_df['weightlbs']
x4 = short_df['time-to-60']
plt.subplot(2,2,1)
sns.barplot(x = 'year', y = x1, data = short_df)
plt.subplot(2,2,2)
sns.barplot(x = 'year', y = x2, data = short_df)
plt.subplot(2,2,3)
sns.barplot(x = 'year', y =x3 , data = short_df)
plt.subplot(2,2,4)
sns.barplot(x = 'year', y =x4 , data = short_df)
plt.show()

# %% [markdown]
# Q3 Create box plots for the following:
#
# a. Create box plots for the columns in the step1 with respect to the number of cylinders and brand respectively.

# %%
fig = plt.subplots(2,2, figsize = (20,10))

plt.subplot(2,2,1)
sns.boxplot(x = 'cylinders', y = 'hp', data = short_df, hue='brand', palette = 'Set2')

plt.subplot(2,2,2)
sns.boxplot(x = 'cylinders', y = 'mpg', data = short_df, hue='brand', palette = 'Set2')

plt.subplot(2,2,3)
sns.boxplot(x = 'cylinders', y = 'weightlbs', data = short_df, hue='brand', palette = 'Set2')

plt.subplot(2,2,4)
sns.boxplot(x = 'cylinders', y = 'time-to-60', data = short_df, hue='brand', palette = 'Set2')
plt.show()

# %% [markdown]
# Q4 Create pair plots for the entire data to study various patterns in the data.
#
# a. Create pair plots with respect to brand, number of cylinders, year, etc.

# %%
short_df.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time-to-60',
#        'year', 'brand'],
#       dtype='object')

# %%
sns.pairplot(short_df)
plt.show()
# Out:
# C:\Users\Rishi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(short_df, hue = 'year')
plt.show()
# Out:
# C:\Users\Rishi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(short_df, hue = 'brand')
plt.show()
# Out:
# C:\Users\Rishi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
Dear Franz Vries,

I'm reaching out to you today to get Referral in your company for the Data Scientist position at OKX ,
I'm a  talented and motivated individual with a strong interest in data science.  
I believe my academic background, passion for the field, and eagerness to learn make me a valuable candidate for your team.
I had recently graduated from institution of roorkee with a degree in Data science and AI . During this time, I demonstrated exceptional academic performance, consistently achieving high grades in relevant courses such as Sql, python, Excel, Power Bi, Pandas, Matplotlib, Numpy, Linux. 
Beyond academics, I  possess a keen eye for detail and a strong analytical mindset, allowing me to approach problems with a logical and data-driven approach.
I am confident that i will be able to quickly adapt to the fast-paced environment of your company and contribute significantly to your team's success.
I request you to review myLinkedIn profile and resume for further details. I would be happy to answer any questions you may have or provide additional information about my qualifications.

Best regards,


Rishiraj Singh
